# %%
import pandas as pd

data = {
    'Ay': ['Ocak', 'Şubat', 'Mart', 'Nisan', 'Mayıs', 'Haziran', 'Temmuz', 'Ağustos', 'Eylül', 'Ekim', 'Kasım', 'Aralık'],
    '2022_Dolar': [13.50, 14.50, 14.80, 15.00, 15.50, 16.00, 17.00, 18.00, 18.50, 19.00, 19.50, 20.00],
    '2022_Euro': [15.20, 15.80, 16.00, 16.50, 16.80, 17.20, 17.50, 18.00, 18.50, 19.00, 19.50, 20.00],
    '2023_Dolar': [20.50, 21.00, 21.50, 22.00, 22.50, 23.00, 24.00, 25.00, 25.50, 26.00, 26.50, 27.00],
    '2023_Euro': [21.00, 21.50, 22.00, 22.50, 23.00, 23.50, 24.00, 25.00, 25.50, 26.00, 26.50, 27.00]
}

df = pd.DataFrame(data)
print(df)
# Out:
#          Ay  2022_Dolar  2022_Euro  2023_Dolar  2023_Euro
# 0      Ocak        13.5       15.2        20.5       21.0
# 1     Şubat        14.5       15.8        21.0       21.5
# 2      Mart        14.8       16.0        21.5       22.0
# 3     Nisan        15.0       16.5        22.0       22.5
# 4     Mayıs        15.5       16.8        22.5       23.0
# 5   Haziran        16.0       17.2        23.0       23.5
# 6    Temmuz        17.0       17.5        24.0       24.0
# 7   Ağustos        18.0       18.0        25.0       25.0
# 8     Eylül        18.5       18.5        25.5       25.5
# 9      Ekim        19.0       19.0        26.0       26.0
# 10    Kasım        19.5       19.5        26.5       26.5
# 11   Aralık        20.0       20.0        27.0       27.0
